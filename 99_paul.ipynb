# %%
from langchain_unstructured import UnstructuredLoader

file_paths = [
    "\data\Day 17_15_01_26.md"
]

loader = UnstructuredLoader(file_paths)

# %%
docs = loader.load()

docs[0]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\paul.rahn\.pyenv\pyenv-win\versions\3.11.3\Lib\site-packages\langchain_unstructured\document_loaders.py:239, in _SingleDocumentLoader._elements_via_local(self)
#     238 try:
# --> 239     from unstructured.partition.auto import partition  # type: ignore
#     240 except ImportError:
#
# ModuleNotFoundError: No module named 'unstructured'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 docs = loader.load()
#       3 docs[0]
#
# File c:\Users\paul.rahn\.pyenv\pyenv-win\versions\3.11.3\Lib\site-packages\langchain_core\document_loaders\base.py:43, in BaseLoader.load(self)
#      37 def load(self) -> list[Document]:
#      38     """Load data into `Document` objects.
#      39
# ...
